# %% [markdown]
# IMPORTO LIBRERIE CHE MI SERVONO:

# %%
import matplotlib as mpl 
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# DATI TRAINING E TEST DI RMSE CON RELATIVI ERRORI:

# %%
Test_size = [ 0.20 , 0.25 , 0.30 , 0.40 , 0.50]
Training_Set_RMSE_PrimaTabella = [0.33470, 0.32994 , 0.32970 , 0.33625,0.33738]
Training_Set_RMSE_SecondaTabella = [0.35748, 0.35716, 0.35327 ,0.36157 , 0.36967]
Training_Set_RMSE_TerzaTabella = [0.37088 ,0.37730 , 0.37410, 0.38963, 0.38568]
Err_Taining_Set_RMSE_PrimaTabella = [0.01475,0.01561 ,0.01658 ,0.02286, 0.03186]
Err_Taining_Set_RMSE_SecondaTabella = [0.01895, 0.01638 ,0.01838, 0.02534 , 0.02952 ]
Err_Taining_Set_RMSE_TerzaTabella = [0.01398,0.01772,0.01868,0.02851 , 0.02954 ]
Test_Set_RMSE_PrimaTabella = [0.90275,0.89695 ,0.89736,0.92217,0.93843]
Test_Set_RMSE_SecondaTabella = [ 0.95970, 0.95847 ,0.99349,0.97818,1.01562]
Test_Set_RMSE_TerzaTabella = [1.01185,0.99165, 1.01572,1.06092 ,1.03694]
Err_Test_Set_RMSE_PrimaTabella = [0.13276,0.11300,0.09003, 0.08783,0.07992]
Err_Test_Set_RMSE_SecondaTabella = [0.15522,0.12291,0.09820, 0.08541,0.08375]
Err_Test_Set_RMSE_TerzaTabella = [0.13678,0.12560 , 0.11069,0.09956, 0.07259 ]

# %% [markdown]
# DATI TRAINING E TEST DI R2 CON RELATIVI ERRORI:

# %%
Training_Set_R2_PrimaTabella = [0.94509, 0.94661, 0.94663,0.94477,0.94284 ]
Err_Training_Set_R2_PrimaTabella = [0.00428,0.00458,0.00544,0.00653,0.00805]
Training_Set_R2_SecondaTabella = [0.93644,0.93740,0.93850,0.93554,0.93237]
Err_Training_Set_R2_SecondaTabella = [0.00511,0.00473,0.00592,0.00815,0.00858]
Training_Set_R2_TerzaTabella = [0.93242,0.93102 , 0.93110, 0.92601, 0.92737]
Err_Training_Set_R2_TerzaTabella = [0.00449,0.00590, 0.00528,0.00872 ,0.00982]
Test_Set_R2_PrimaTabella = [0.54866,0.58006,0.58027,0.56170, 0.56206]
Err_Test_Set_R2_PrimaTabella = [0.15964,0.09387,0.08524,0.09556,0.06547]
Test_Set_R2_SecondaTabella = [0.53519,0.52005,0.49730, 0.51341, 0.48384]
Err_Test_Set_R2_SecondaTabella = [0.13420,0.10029, 0.09119,0.08397,0.08786]
Test_Set_R2_TerzaTabella = [0.46732,0.47215,0.47808, 0.41868,0.45743]
Err_Test_Set_R2_TerzaTabella = [0.13127,0.12520,0.08037,0.10722,0.06622 ]

# %% [markdown]
# GRAFICO RMSE:

# %%
Test_size = [ 0.20 , 0.25 , 0.30 , 0.40 , 0.50]
Training_Set_RMSE_PrimaTabella = [0.33470, 0.32994 , 0.32970 , 0.33625,0.33738]
Training_Set_RMSE_SecondaTabella = [0.35748, 0.35716, 0.35327 ,0.36157 , 0.36967]
Training_Set_RMSE_TerzaTabella = [0.37088 ,0.37730 , 0.37410, 0.38963, 0.38568]
Err_Taining_Set_RMSE_PrimaTabella = [0.01475,0.01561 ,0.01658 ,0.02286, 0.03186]
Err_Taining_Set_RMSE_SecondaTabella = [0.01895, 0.01638 ,0.01838, 0.02534 , 0.02952 ]
Err_Taining_Set_RMSE_TerzaTabella = [0.01398,0.01772,0.01868,0.02851 , 0.02954 ]
Test_Set_RMSE_PrimaTabella = [0.90275,0.89695 ,0.89736,0.92217,0.93843]
Test_Set_RMSE_SecondaTabella = [ 0.95970, 0.95847 ,0.99349,0.97818,1.01562]
Test_Set_RMSE_TerzaTabella = [1.01185,0.99165, 1.01572,1.06092 ,1.03694]
Err_Test_Set_RMSE_PrimaTabella = [0.13276,0.11300,0.09003, 0.08783,0.07992]
Err_Test_Set_RMSE_SecondaTabella = [0.15522,0.12291,0.09820, 0.08541,0.08375]
Err_Test_Set_RMSE_TerzaTabella = [0.13678,0.12560 , 0.11069,0.09956, 0.07259 ]

fig , ax = plt.subplots()
ax.set_title('RMSE')
ax.set_xlabel('Test Size Split')
ax.set_ylabel('Training ~ Test')
plt.axis([ 0 , 0.75 , 0 , 1.20])
plt.plot(Test_size, Training_Set_RMSE_PrimaTabella ,'ro' , label= "Tab1 Training" )
ax.errorbar(Test_size, Training_Set_RMSE_PrimaTabella, Err_Taining_Set_RMSE_PrimaTabella, fmt='none', ecolor='r', linewidth=1, capsize=6)
plt.plot(Test_size, Training_Set_RMSE_SecondaTabella ,'bo' , label= "Tab2 Training" )
ax.errorbar(Test_size, Training_Set_RMSE_SecondaTabella, Err_Taining_Set_RMSE_SecondaTabella, fmt='none', ecolor='b', linewidth=1, capsize=6)
plt.plot(Test_size, Training_Set_RMSE_TerzaTabella ,'go' , label= "Tab3 Training" )
ax.errorbar(Test_size, Training_Set_RMSE_TerzaTabella, Err_Taining_Set_RMSE_TerzaTabella, fmt='none', ecolor='g', linewidth=1, capsize=6)
plt.plot(Test_size, Test_Set_RMSE_PrimaTabella ,'r^' , label= "Tab1 Test" )
ax.errorbar(Test_size, Test_Set_RMSE_PrimaTabella, Err_Test_Set_RMSE_PrimaTabella, fmt='none', ecolor='r', linewidth=1, capsize=6)
plt.plot(Test_size, Test_Set_RMSE_SecondaTabella ,'b^' , label= "Tab2 Test" )
ax.errorbar(Test_size, Test_Set_RMSE_SecondaTabella, Err_Test_Set_RMSE_SecondaTabella, fmt='none', ecolor='b', linewidth=1, capsize=6)
plt.plot(Test_size, Test_Set_RMSE_TerzaTabella ,'g^' , label= "Tab3 Test" )
ax.errorbar(Test_size, Test_Set_RMSE_TerzaTabella, Err_Test_Set_RMSE_TerzaTabella, fmt='none', ecolor='g', linewidth=1, capsize=6)
ax.legend()

# %% [markdown]
# GRAFICO R2:

# %%
Test_size = [ 0.20 , 0.25 , 0.30 , 0.40 , 0.50]
Training_Set_R2_PrimaTabella = [0.94509, 0.94661, 0.94663,0.94477,0.94284 ]
Err_Training_Set_R2_PrimaTabella = [0.00428,0.00458,0.00544,0.00653,0.00805]
Training_Set_R2_SecondaTabella = [0.93644,0.93740,0.93850,0.93554,0.93237]
Err_Training_Set_R2_SecondaTabella = [0.00511,0.00473,0.00592,0.00815,0.00858]
Training_Set_R2_TerzaTabella = [0.93242,0.93102 , 0.93110, 0.92601, 0.92737]
Err_Training_Set_R2_TerzaTabella = [0.00449,0.00590, 0.00528,0.00872 ,0.00982]
Test_Set_R2_PrimaTabella = [0.54866,0.58006,0.58027,0.56170, 0.56206]
Err_Test_Set_R2_PrimaTabella = [0.15964,0.09387,0.08524,0.09556,0.06547]
Test_Set_R2_SecondaTabella = [0.53519,0.52005,0.49730, 0.51341, 0.48384]
Err_Test_Set_R2_SecondaTabella = [0.13420,0.10029, 0.09119,0.08397,0.08786]
Test_Set_R2_TerzaTabella = [0.46732,0.47215,0.47808, 0.41868,0.45743]
Err_Test_Set_R2_TerzaTabella = [0.13127,0.12520,0.08037,0.10722,0.06622 ]
fig , ax = plt.subplots()
ax.set_title('R2')
ax.set_xlabel('Test Size Split')
ax.set_ylabel('Training ~ Test')
plt.axis([ 0 , 0.75 , 0 , 1.20])
plt.plot(Test_size, Training_Set_R2_PrimaTabella ,'ro' , label= "Tab1 Training" )
ax.errorbar(Test_size, Training_Set_R2_PrimaTabella, Err_Training_Set_R2_PrimaTabella, fmt='none', ecolor='r', linewidth=1, capsize=6)
plt.plot(Test_size, Training_Set_R2_SecondaTabella ,'bo' , label= "Tab2 Training" )
ax.errorbar(Test_size, Training_Set_R2_SecondaTabella, Err_Training_Set_R2_SecondaTabella, fmt='none', ecolor='b', linewidth=1, capsize=6)
plt.plot(Test_size, Training_Set_R2_TerzaTabella ,'go' , label= "Tab3 Training" )
ax.errorbar(Test_size, Training_Set_R2_TerzaTabella, Err_Training_Set_R2_TerzaTabella, fmt='none', ecolor='g', linewidth=1, capsize=6)
plt.plot(Test_size, Test_Set_R2_PrimaTabella ,'r^' , label= "Tab1 Test" )
ax.errorbar(Test_size, Test_Set_R2_PrimaTabella, Err_Test_Set_R2_PrimaTabella, fmt='none', ecolor='r', linewidth=1, capsize=6)
plt.plot(Test_size, Test_Set_R2_SecondaTabella ,'b^' , label= "Tab2 Test" )
ax.errorbar(Test_size, Test_Set_R2_SecondaTabella, Err_Test_Set_R2_SecondaTabella, fmt='none', ecolor='b', linewidth=1, capsize=6)
plt.plot(Test_size, Test_Set_R2_TerzaTabella ,'g^' , label= "Tab3 Test" )
ax.errorbar(Test_size, Test_Set_R2_TerzaTabella, Err_Test_Set_R2_TerzaTabella, fmt='none', ecolor='g', linewidth=1, capsize=6)
ax.legend()

# %% [markdown]
# Massimo e Minimo Training RMSE:

# %%
Training_Set_RMSE_PrimaTabella = [0.33470, 0.32994 , 0.32970 , 0.33625,0.33738]
Training_Set_RMSE_SecondaTabella = [0.35748, 0.35716, 0.35327 ,0.36157 , 0.36967]
Training_Set_RMSE_TerzaTabella = [0.37088 ,0.37730 , 0.37410, 0.38963, 0.38568]
list1 = Training_Set_RMSE_PrimaTabella + Training_Set_RMSE_SecondaTabella + Training_Set_RMSE_TerzaTabella
Massimo_Training_RMSE = max(list1)
Minimo_Training_RMSE = min(list1)
print(Massimo_Training_RMSE)
print(Minimo_Training_RMSE)
max_Training_RMSE = (0.40 , Massimo_Training_RMSE) # toupla con: primo elemento il testplit ed il secondo elemento il valore di Training RMSE piu' grande 
min_Traininig_RMSE = (0.30 , Minimo_Training_RMSE) # toupla con: primo elemento il testplit ed il secondo elemento il valore di Training RMSE piu' piccolo
# Out:
# 0.38963
# 0.3297

# %% [markdown]
# Massimo e Minimo Test RMSE:

# %%
Test_Set_RMSE_PrimaTabella = [0.90275,0.89695 ,0.89736,0.92217,0.93843]
Test_Set_RMSE_SecondaTabella = [ 0.95970, 0.95847 ,0.99349,0.97818,1.01562]
Test_Set_RMSE_TerzaTabella = [1.01185,0.99165, 1.01572,1.06092 ,1.03694]
list2 = Test_Set_RMSE_PrimaTabella + Test_Set_RMSE_SecondaTabella + Test_Set_RMSE_TerzaTabella
Massimo_Test_RMSE = max(list2)
Minimo_Test_RMSE = min(list2)
print(Massimo_Test_RMSE)
print(Minimo_Test_RMSE)
max_Test_RMSE = (0.40 , Massimo_Test_RMSE)
min_Test_RMSE = (0.25 , Minimo_Test_RMSE)
# Out:
# 1.06092
# 0.89695

# %% [markdown]
# Massimmo e Minimo Training R2:

# %%
Training_Set_R2_PrimaTabella = [0.94509, 0.94661, 0.94663,0.94477,0.94284 ]
Training_Set_R2_SecondaTabella = [0.93644,0.93740,0.93850,0.93554,0.93237]
Training_Set_R2_TerzaTabella = [0.93242,0.93102 , 0.93110, 0.92601, 0.92737]
list3 = Training_Set_R2_PrimaTabella + Training_Set_R2_SecondaTabella + Training_Set_R2_TerzaTabella
Massimo_Training_R2 = max(list3)
Minimo_Training_R2 = min(list3)
print(Massimo_Training_R2)
print(Minimo_Training_R2)
max_Training_R2 = (0.30 , Massimo_Training_R2)
min_Training_R2 = (0.40 , Minimo_Training_R2)
# Out:
# 0.94663
# 0.92601

# %% [markdown]
# Massimo e Minimo Test R2:

# %%
Test_Set_R2_PrimaTabella = [0.54866,0.58006,0.58027,0.56170, 0.56206]
Test_Set_R2_SecondaTabella = [0.53519,0.52005,0.49730, 0.51341, 0.48384]
Test_Set_R2_TerzaTabella = [0.46732,0.47215,0.47808, 0.41868,0.45743]
list4 = Test_Set_R2_PrimaTabella + Test_Set_R2_SecondaTabella + Test_Set_R2_TerzaTabella
Massimo_Test_R2 = max(list4)
Minimo_Test_R2 = min(list4)
print(Massimo_Test_R2)
print(Minimo_Test_R2)
max_Test_R2 = (0.30 , Massimo_Test_R2)
min_Test_R2 = (0.40 , Minimo_Test_R2)
# Out:
# 0.58027
# 0.41868
