# %%
'''
i'm trying to understanding what should i do.
different plots for test size 030 and 025.
for each test size there are 6 plots 3 Training and 3 Test with different numbers of features: 
'''
# Out:
# "\ni'm trying to understanding what should i do.\ndifferent plots for test size 030 and 025.\nfor each test size there are 6 plots 3 Training and 3 Test with different numbers of features: \n"

# %%
import pandas as pd 
import numpy as np 
import matplotlib as mpl 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
# In this cell i'm reading datas from cdv files:
df1Training = pd.read_csv('/Users/giuspru/Documents/Tesi_mac/Test_Split_25_N200/Tabella1_025_N200_Training.csv')
df1Test = pd.read_csv('/Users/giuspru/Documents/Tesi_mac/Test_Split_25_N200/Tabella1_025_N200_Test.csv')
df2Training = pd.read_csv('/Users/giuspru/Documents/Tesi_mac/Test_Split_25_N200/Tabella2_025_N200_Training.csv')
df2Test = pd.read_csv('/Users/giuspru/Documents/Tesi_mac/Test_Split_25_N200/Tabella2_025_N200_Test.csv')
df3Training = pd.read_csv('/Users/giuspru/Documents/Tesi_mac/Test_Split_25_N200/Tabella3_025_N200_Training.csv')
df3Test = pd.read_csv('/Users/giuspru/Documents/Tesi_mac/Test_Split_25_N200/Tabella3_025_N200_Test.csv')

# %%
df3Test
# Out:
#                Features                         ind1   \
# 0               Density       0.00804 +/-    0.03433
# 1         Depriv. Index       0.34388 +/-    0.13389
# 2       Old Young Ratio       0.01867 +/-    0.03796
# 3             Avg. PM10       0.24587 +/-    0.12707
# 4               Avg. NO       0.30008 +/-    0.14697
# 5             Avg. PANS       0.03316 +/-    0.03571
# 6              Avg. SO2       0.04365 +/-    0.04069
# 7          Random Feat.       0.00783 +/-    0.03069
#
#                          ind2    RMSE prima Posizione   \
# 0      0.00515 +/-    0.01786                      0.0
# 1      0.17011 +/-    0.05428                     61.5
# 2      0.00908 +/-    0.02043                      0.0
# 3      0.11531 +/-    0.05491                      5.5
# 4      0.14255 +/-    0.05606                     32.5
# 5      0.01926 +/-    0.01934                      0.5
# 6      0.02118 +/-    0.02177                      0.0
# ...

# %%
# In this cell i created y values , and 2 arrays , x1 contains x axis values and x2 their errors 
y1_Training = df1Training["Features "]
f_importace_Training = df1Training["   ind1 "].str.split(expand = True)
x1_Training = []
x2_Training = []
for i in f_importace_Training[0]:
    x1_Training.append(float(i))

for i in f_importace_Training[2]:
    x2_Training.append(float(i))

# %%
y1_Training = df1Training["Features "]
f_importace_Training = df1Training["   ind1 "].str.split(expand = True)
x1_Training = []
x2_Training = []
for i in f_importace_Training[0]:
    x1_Training.append(float(i))

for i in f_importace_Training[2]:
    x2_Training.append(float(i))
#y_pos = np.arange(len(y1)) 
fig , ax = plt.subplots(figsize=(20,10))
ax.barh(y1_Training , x1_Training , xerr = x2_Training , align = 'center' , capsize = 6 , color ='b')
plt.xticks(np.arange(0,1,0.05))
ax.invert_yaxis()
ax.set_xlabel('Feature Importance ')
ax.set_title(' Training RMSE Feature Importance full sett: test size 025' )
# Out:
# Text(0.5, 1.0, ' Training RMSE Feature Importance full sett: test size 025')

# %%
y1_Test = df1Test["Features "]
f_importace_Test = df1Test["   ind1 "].str.split(expand = True)
x1_Test = []
x2_Test = []
for i in f_importace_Test[0]:
    x1_Test.append(float(i))

for i in f_importace_Test[2]:
    x2_Test.append(float(i))
#y_pos = np.arange(len(y1)) 
fig , ax = plt.subplots(figsize=(20,10))
ax.barh(y1_Test , x1_Test , xerr = x2_Test , align = 'center' , capsize = 6 , color ='b')
plt.xticks(np.arange(0,1,0.05))
ax.invert_yaxis()
ax.set_xlabel('Feature Importance ')
ax.set_title('Test RMSE Feature Importance full sett: test size 025' )
# Out:
# Text(0.5, 1.0, 'Test RMSE Feature Importance full sett: test size 025')

# %%
y2_Training = df2Training["Features "]
f_importace_Training = df2Training["   ind1 "].str.split(expand = True)
x3_Training = []
x4_Training = []
for i in f_importace_Training[0]:
    x3_Training.append(float(i))

for i in f_importace_Training[2]:
    x4_Training.append(float(i))
#y_pos = np.arange(len(y1)) 
fig , ax = plt.subplots(figsize=(20,10))
ax.barh(y2_Training , x3_Training , xerr = x4_Training , align = 'center' , capsize = 6 , color ='b')
plt.xticks(np.arange(0,1,0.05))
ax.invert_yaxis()
ax.set_xlabel('Feature Importance ')
ax.set_title(' Fefature importance Training RMSE without latitute: test size 025' )
# Out:
# Text(0.5, 1.0, ' Fefature importance Training RMSE without latitute: test size 025')

# %%
y2_Test = df2Test["Features "]
f_importace_Test = df2Test["   ind1 "].str.split(expand = True)
x3_Test = []
x4_Test = []
for i in f_importace_Test[0]:
    x3_Test.append(float(i))

for i in f_importace_Test[2]:
    x4_Test.append(float(i))
#y_pos = np.arange(len(y1)) 
fig , ax = plt.subplots(figsize=(20,10))
ax.barh(y2_Test , x3_Test , xerr = x4_Test , align = 'center' , capsize = 6 , color ='b')
plt.xticks(np.arange(0,1,0.05))
ax.invert_yaxis()
ax.set_xlabel('Feature Importance ')
ax.set_title('Feature Importance Test RMSE without latitude: test size 025' )
# Out:
# Text(0.5, 1.0, 'Feature Importance Test RMSE without latitude: test size 025')

# %%
y3_Training = df3Training["Features "]
f_importace_Training = df3Training["   ind1 "].str.split(expand = True)
x5_Training = []
x6_Training = []
for i in f_importace_Training[0]:
    x5_Training.append(float(i))

for i in f_importace_Training[2]:
    x6_Training.append(float(i))
#y_pos = np.arange(len(y1)) 
fig , ax = plt.subplots(figsize=(20,10))
ax.barh(y3_Training , x5_Training , xerr = x6_Training , align = 'center' , capsize = 6 , color ='b')
plt.xticks(np.arange(0,1,0.05))
ax.invert_yaxis()
ax.set_xlabel('Feature Importance ')
ax.set_title(' Fefature importance Training RMSE without latitute & comm. density: test size 025' )
# Out:
# Text(0.5, 1.0, ' Fefature importance Training RMSE without latitute & comm. density: test size 025')

# %%
y3_Test = df3Test["Features "]
f_importace_Test = df3Test["   ind1 "].str.split(expand = True)
x5_Test = []
x6_Test = []
for i in f_importace_Test[0]:
    x5_Test.append(float(i))

for i in f_importace_Test[2]:
    x6_Test.append(float(i))
#y_pos = np.arange(len(y1)) 
fig , ax = plt.subplots(figsize=(20,10))
ax.barh(y3_Test , x5_Test , xerr = x6_Test , align = 'center' , capsize = 6 , color ='b')
plt.xticks(np.arange(0,1,0.05))
ax.invert_yaxis()
ax.set_xlabel('Feature Importance ')
ax.set_title('Feature Importance Test RMSE without latitude: test size 025' )
# Out:
# Text(0.5, 1.0, 'Feature Importance Test RMSE without latitude: test size 025')

# %%
df1Training
# Out:
#                Features                         ind1   \
# 0               Density       0.05253 +/-    0.00768
# 1          Com. Density       0.25195 +/-    0.04016
# 2         Depriv. Index       0.10679 +/-    0.02169
# 3              Latitude       0.68402 +/-    0.07271
# 4       Old Young Ratio       0.08613 +/-    0.01889
# 5             Avg. PM10       0.15611 +/-    0.03574
# 6               Avg. NO       0.20293 +/-    0.04562
# 7             Avg. PANS       0.05013 +/-    0.01101
# 8              Avg. SO2       0.06589 +/-    0.01256
# 9          Random Feat.       0.07368 +/-    0.01648
#
#                          ind2    RMSE prima Posizione   \
# 0     -0.00525 +/-    0.01012                      0.0
# 1      0.06938 +/-    0.03684                      0.0
# 2      0.01329 +/-    0.01973                      0.0
# 3      0.28289 +/-    0.05829                    100.0
# 4      0.00726 +/-    0.01734                      0.0
# ...

# %%
y1_Training = df1Training["Features "]
f_importace_Training = df1Training[" ind2 "].str.split(expand = True)
x1_Training = []
x2_Training = []
for i in f_importace_Training[0]:
    x1_Training.append(float(i))

for i in f_importace_Training[2]:
    x2_Training.append(float(i))
#y_pos = np.arange(len(y1)) 
fig , ax = plt.subplots(figsize=(20,10))
ax.barh(y1_Training , x1_Training , xerr = x2_Training , align = 'center' , capsize = 6 , color ='b')
plt.xticks(np.arange(0,1,0.05))
ax.invert_yaxis()
ax.set_xlabel('Feature Importance ')
ax.set_title(' Training R2 Feature Importance full sett: test size 025' )
# Out:
# Text(0.5, 1.0, ' Training R2 Feature Importance full sett: test size 025')

# %%
y1_Test = df1Test["Features "]
f_importace_Test = df1Test[" ind2 "].str.split(expand = True)
x1_Test = []
x2_Test = []
for i in f_importace_Test[0]:
    x1_Test.append(float(i))

for i in f_importace_Test[2]:
    x2_Test.append(float(i))
#y_pos = np.arange(len(y1)) 
fig , ax = plt.subplots(figsize=(20,10))
ax.barh(y1_Test , x1_Test , xerr = x2_Test , align = 'center' , capsize = 6 , color ='b')
plt.xticks(np.arange(0,1,0.05))
ax.invert_yaxis()
ax.set_xlabel('Feature Importance ')
ax.set_title('Test R2 Feature Importance full sett: test size 025' )
# Out:
# Text(0.5, 1.0, 'Test R2 Feature Importance full sett: test size 025')

# %%
y2_Training = df2Training["Features "]
f_importace_Training = df2Training[" ind2 "].str.split(expand = True)
x3_Training = []
x4_Training = []
for i in f_importace_Training[0]:
    x3_Training.append(float(i))

for i in f_importace_Training[2]:
    x4_Training.append(float(i))
#y_pos = np.arange(len(y1)) 
fig , ax = plt.subplots(figsize=(20,10))
ax.barh(y2_Training , x3_Training , xerr = x4_Training , align = 'center' , capsize = 6 , color ='b')
plt.xticks(np.arange(0,1,0.05))
ax.invert_yaxis()
ax.set_xlabel('Feature Importance ')
ax.set_title(' Fefature importance Training R2 without latitute: test size 025' )
# Out:
# Text(0.5, 1.0, ' Fefature importance Training R2 without latitute: test size 025')

# %%
y2_Test = df2Test["Features "]
f_importace_Test = df2Test[" ind2 "].str.split(expand = True)
x3_Test = []
x4_Test = []
for i in f_importace_Test[0]:
    x3_Test.append(float(i))

for i in f_importace_Test[2]:
    x4_Test.append(float(i))
#y_pos = np.arange(len(y1)) 
fig , ax = plt.subplots(figsize=(20,10))
ax.barh(y2_Test , x3_Test , xerr = x4_Test , align = 'center' , capsize = 6 , color ='b')
plt.xticks(np.arange(0,1,0.05))
ax.invert_yaxis()
ax.set_xlabel('Feature Importance ')
ax.set_title('Feature Importance Test R2 without latitude: test size 025' )
# Out:
# Text(0.5, 1.0, 'Feature Importance Test R2 without latitude: test size 025')

# %%
y3_Training = df3Training["Features "]
f_importace_Training = df3Training[" ind2 "].str.split(expand = True)
x5_Training = []
x6_Training = []
for i in f_importace_Training[0]:
    x5_Training.append(float(i))

for i in f_importace_Training[2]:
    x6_Training.append(float(i))
#y_pos = np.arange(len(y1)) 
fig , ax = plt.subplots(figsize=(20,10))
ax.barh(y3_Training , x5_Training , xerr = x6_Training , align = 'center' , capsize = 6 , color ='b')
plt.xticks(np.arange(0,1,0.05))
ax.invert_yaxis()
ax.set_xlabel('Feature Importance ')
ax.set_title(' Fefature importance Training R2 without latitute & comm. density: test size 025' )
# Out:
# Text(0.5, 1.0, ' Fefature importance Training R2 without latitute & comm. density: test size 025')

# %%
y3_Test = df3Test["Features "]
f_importace_Test = df3Test[" ind2 "].str.split(expand = True)
x5_Test = []
x6_Test = []
for i in f_importace_Test[0]:
    x5_Test.append(float(i))

for i in f_importace_Test[2]:
    x6_Test.append(float(i))
#y_pos = np.arange(len(y1)) 
fig , ax = plt.subplots(figsize=(20,10))
ax.barh(y3_Test , x5_Test , xerr = x6_Test , align = 'center' , capsize = 6 , color ='b')
plt.xticks(np.arange(0,1,0.05))
ax.invert_yaxis()
ax.set_xlabel('Feature Importance ')
ax.set_title('Feature Importance Test R2 without latitude: test size 025' )
# Out:
# Text(0.5, 1.0, 'Feature Importance Test R2 without latitude: test size 025')
