# %%
import pandas as pd 
import numpy as np 
import matplotlib as mpl 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
df1Training = pd.read_csv('/Users/giuspru/Documents/Tesi_mac/Test_Split_30_N200/Tabella1_030_N200_Training.csv')
df1Test = pd.read_csv('/Users/giuspru/Documents/Tesi_mac/Test_Split_30_N200/Tabella1_030_N200_Test.csv')
df2Training = pd.read_csv('/Users/giuspru/Documents/Tesi_mac/Test_Split_30_N200/Tabella2_030_N200_Training.csv')
df2Test = pd.read_csv('/Users/giuspru/Documents/Tesi_mac/Test_Split_30_N200/Tabella2_030_N200_Test.csv')
df3Training = pd.read_csv('/Users/giuspru/Documents/Tesi_mac/Test_Split_30_N200/Tabella3_030_N200_Training.csv')
df3Test = pd.read_csv('/Users/giuspru/Documents/Tesi_mac/Test_Split_30_N200/Tabella3_030_N200_Test.csv')

# %%
df3Test
# Out:
#                Features                         ind1   \
# 0               Density       0.00967 +/-    0.02914
# 1         Depriv. Index       0.33310 +/-    0.11028
# 2       Old Young Ratio       0.01596 +/-    0.03834
# 3             Avg. PM10       0.25529 +/-    0.10999
# 4               Avg. NO       0.31007 +/-    0.12601
# 5             Avg. PANS       0.03380 +/-    0.03133
# 6              Avg. SO2       0.03744 +/-    0.03357
# 7          Random Feat.       0.01006 +/-    0.02797
#
#                          ind2    RMSE prima Posizione   \
# 0      0.00386 +/-    0.01468                      0.0
# 1      0.16933 +/-    0.04750                     56.0
# 2      0.00780 +/-    0.01963                      0.0
# 3      0.12522 +/-    0.04427                      8.0
# 4      0.15096 +/-    0.05091                     36.0
# 5      0.01857 +/-    0.01791                      0.0
# 6      0.01840 +/-    0.01670                      0.0
# 7      0.00506 +/-    0.01469                      0.0
#
#     RMSE Seconda Posizione    R2 Prima Posizione    R2 Seconda Posizione
# 0                       0.0                   0.0                     0.0
# 1                      28.0                  57.5                    25.5
# 2                       0.0                   0.0                     0.0
# 3                      30.0                   8.5                    32.0
# 4                      41.0                  34.0                    42.5
# 5                       1.0                   0.0                     0.0
# 6                       0.0                   0.0                     0.0
# 7                       0.0                   0.0                     0.0

# %%
y1_Training = df1Training["         Features "]
f_importace_Training = df1Training["   ind1 "].str.split(expand = True)
x1_Training = []
x2_Training = []
for i in f_importace_Training[0]:
    x1_Training.append(float(i))

for i in f_importace_Training[2]:
    x2_Training.append(float(i))
#y_pos = np.arange(len(y1)) 
fig , ax = plt.subplots(figsize=(20,10))
ax.barh(y1_Training , x1_Training , xerr = x2_Training , align = 'center' , capsize = 6 , color ='b')
plt.xticks(np.arange(0,1,0.05))
ax.invert_yaxis()
ax.set_xlabel('Feature Importance ')
ax.set_title(' Training RMSE Feature Importance full sett: test size 030' )
# Out:
# Text(0.5, 1.0, ' Training RMSE Feature Importance full sett: test size 030')

# %%
y1_Test = df1Test["            Features "]
f_importace_Test = df1Test["   ind1 "].str.split(expand = True)
x1_Test = []
x2_Test = []
for i in f_importace_Test[0]:
    x1_Test.append(float(i))

for i in f_importace_Test[2]:
    x2_Test.append(float(i))
#y_pos = np.arange(len(y1)) 
fig , ax = plt.subplots(figsize=(20,10))
ax.barh(y1_Test , x1_Test , xerr = x2_Test , align = 'center' , capsize = 6 , color ='b')
plt.xticks(np.arange(0,1,0.05))
ax.invert_yaxis()
ax.set_xlabel('Feature Importance ')
ax.set_title('Test RMSE Feature Importance full sett: test size 030' )
# Out:
# Text(0.5, 1.0, 'Test RMSE Feature Importance full sett: test size 030')

# %%
y2_Training = df2Training["            Features "]
f_importace_Training = df2Training["   ind1 "].str.split(expand = True)
x3_Training = []
x4_Training = []
for i in f_importace_Training[0]:
    x3_Training.append(float(i))

for i in f_importace_Training[2]:
    x4_Training.append(float(i))
#y_pos = np.arange(len(y1)) 
fig , ax = plt.subplots(figsize=(20,10))
ax.barh(y2_Training , x3_Training , xerr = x4_Training , align = 'center' , capsize = 6 , color ='b')
plt.xticks(np.arange(0,1,0.05))
ax.invert_yaxis()
ax.set_xlabel('Feature Importance ')
ax.set_title(' Fefature importance Training RMSE without latitute: test size 030' )
# Out:
# Text(0.5, 1.0, ' Fefature importance Training RMSE without latitute: test size 030')

# %%
y2_Test = df2Test["             Features "]
f_importace_Test = df2Test["   ind1 "].str.split(expand = True)
x3_Test = []
x4_Test = []
for i in f_importace_Test[0]:
    x3_Test.append(float(i))

for i in f_importace_Test[2]:
    x4_Test.append(float(i))
#y_pos = np.arange(len(y1)) 
fig , ax = plt.subplots(figsize=(20,10))
ax.barh(y2_Test , x3_Test , xerr = x4_Test , align = 'center' , capsize = 6 , color ='b')
plt.xticks(np.arange(0,1,0.05))
ax.invert_yaxis()
ax.set_xlabel('Feature Importance ')
ax.set_title('Feature Importance Test RMSE without latitude: test size 030' )
# Out:
# Text(0.5, 1.0, 'Feature Importance Test RMSE without latitude: test size 030')

# %%
y3_Training = df3Training["             Features "]
f_importace_Training = df3Training["   ind1 "].str.split(expand = True)
x5_Training = []
x6_Training = []
for i in f_importace_Training[0]:
    x5_Training.append(float(i))

for i in f_importace_Training[2]:
    x6_Training.append(float(i))
#y_pos = np.arange(len(y1)) 
fig , ax = plt.subplots(figsize=(20,10))
ax.barh(y3_Training , x5_Training , xerr = x6_Training , align = 'center' , capsize = 6 , color ='b')
plt.xticks(np.arange(0,1,0.05))
ax.invert_yaxis()
ax.set_xlabel('Feature Importance ')
ax.set_title(' Fefature importance Training RMSE without latitute & comm. density: test size 030' )
# Out:
# Text(0.5, 1.0, ' Fefature importance Training RMSE without latitute & comm. density: test size 030')

# %%
y3_Test = df3Test["             Features "]
f_importace_Test = df3Test["   ind1 "].str.split(expand = True)
x5_Test = []
x6_Test = []
for i in f_importace_Test[0]:
    x5_Test.append(float(i))

for i in f_importace_Test[2]:
    x6_Test.append(float(i))
#y_pos = np.arange(len(y1)) 
fig , ax = plt.subplots(figsize=(20,10))
ax.barh(y3_Test , x5_Test , xerr = x6_Test , align = 'center' , capsize = 6 , color ='b')
plt.xticks(np.arange(0,1,0.05))
ax.invert_yaxis()
ax.set_xlabel('Feature Importance ')
ax.set_title('Feature Importance Test RMSE without latitude: test size 030' )
# Out:
# Text(0.5, 1.0, 'Feature Importance Test RMSE without latitude: test size 030')

# %%
y1_Training = df1Training["         Features "]
f_importace_Training = df1Training[" ind2 "].str.split(expand = True)
x1_Training = []
x2_Training = []
for i in f_importace_Training[0]:
    x1_Training.append(float(i))

for i in f_importace_Training[2]:
    x2_Training.append(float(i))
#y_pos = np.arange(len(y1)) 
fig , ax = plt.subplots(figsize=(20,10))
ax.barh(y1_Training , x1_Training , xerr = x2_Training , align = 'center' , capsize = 6 , color ='b')
plt.xticks(np.arange(0,1,0.05))
ax.invert_yaxis()
ax.set_xlabel('Feature Importance ')
ax.set_title(' Training R2 Feature Importance full sett: test size 0.30' )
# Out:
# Text(0.5, 1.0, ' Training R2 Feature Importance full sett: test size 0.30')

# %%
y1_Test = df1Test["            Features "]
f_importace_Test = df1Test[" ind2 "].str.split(expand = True)
x1_Test = []
x2_Test = []
for i in f_importace_Test[0]:
    x1_Test.append(float(i))

for i in f_importace_Test[2]:
    x2_Test.append(float(i))
#y_pos = np.arange(len(y1)) 
fig , ax = plt.subplots(figsize=(20,10))
ax.barh(y1_Test , x1_Test , xerr = x2_Test , align = 'center' , capsize = 6 , color ='b')
plt.xticks(np.arange(0,1,0.05))
ax.invert_yaxis()
ax.set_xlabel('Feature Importance ')
ax.set_title('Test R2 Feature Importance full sett: test size 0.30' )
# Out:
# Text(0.5, 1.0, 'Test R2 Feature Importance full sett: test size 0.30')

# %%
y2_Training = df2Training["            Features "]
f_importace_Training = df2Training[" ind2 "].str.split(expand = True)
x3_Training = []
x4_Training = []
for i in f_importace_Training[0]:
    x3_Training.append(float(i))

for i in f_importace_Training[2]:
    x4_Training.append(float(i))
#y_pos = np.arange(len(y1)) 
fig , ax = plt.subplots(figsize=(20,10))
ax.barh(y2_Training , x3_Training , xerr = x4_Training , align = 'center' , capsize = 6 , color ='b')
plt.xticks(np.arange(0,1,0.05))
ax.invert_yaxis()
ax.set_xlabel('Feature Importance ')
ax.set_title(' Fefature importance Training R2 without latitute: test size 0.30' )
# Out:
# Text(0.5, 1.0, ' Fefature importance Training R2 without latitute: test size 0.30')

# %%
y2_Test = df2Test["             Features "]
f_importace_Test = df2Test[" ind2 "].str.split(expand = True)
x3_Test = []
x4_Test = []
for i in f_importace_Test[0]:
    x3_Test.append(float(i))

for i in f_importace_Test[2]:
    x4_Test.append(float(i))
#y_pos = np.arange(len(y1)) 
fig , ax = plt.subplots(figsize=(20,10))
ax.barh(y2_Test , x3_Test , xerr = x4_Test , align = 'center' , capsize = 6 , color ='b')
plt.xticks(np.arange(0,1,0.05))
ax.invert_yaxis()
ax.set_xlabel('Feature Importance ')
ax.set_title('Feature Importance Test R2 without latitude: test size 0.30' )
# Out:
# Text(0.5, 1.0, 'Feature Importance Test R2 without latitude: test size 0.30')

# %%
y3_Training = df3Training["             Features "]
f_importace_Training = df3Training[" ind2 "].str.split(expand = True)
x5_Training = []
x6_Training = []
for i in f_importace_Training[0]:
    x5_Training.append(float(i))

for i in f_importace_Training[2]:
    x6_Training.append(float(i))
#y_pos = np.arange(len(y1)) 
fig , ax = plt.subplots(figsize=(20,10))
ax.barh(y3_Training , x5_Training , xerr = x6_Training , align = 'center' , capsize = 6 , color ='b')
plt.xticks(np.arange(0,1,0.05))
ax.invert_yaxis()
ax.set_xlabel('Feature Importance ')
ax.set_title(' Fefature importance Training R2 without latitute & comm. density: test size 0.30' )
# Out:
# Text(0.5, 1.0, ' Fefature importance Training R2 without latitute & comm. density: test size 0.30')

# %%
y3_Test = df3Test["             Features "]
f_importace_Test = df3Test[" ind2 "].str.split(expand = True)
x5_Test = []
x6_Test = []
for i in f_importace_Test[0]:
    x5_Test.append(float(i))

for i in f_importace_Test[2]:
    x6_Test.append(float(i))
#y_pos = np.arange(len(y1)) 
fig , ax = plt.subplots(figsize=(20,10))
ax.barh(y3_Test , x5_Test , xerr = x6_Test , align = 'center' , capsize = 6 , color ='b')
plt.xticks(np.arange(0,1,0.05))
ax.invert_yaxis()
ax.set_xlabel('Feature Importance ')
ax.set_title('Feature Importance Test R2 without latitude: test size 0.30' )
# Out:
# Text(0.5, 1.0, 'Feature Importance Test R2 without latitude: test size 0.30')
