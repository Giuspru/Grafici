# %%
import pandas as pd 
import numpy as np 
import matplotlib as mpl 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1Training = pd.read_csv('/Users/giuspru/Documents/Tesi_mac/Test_Split_25_N200/Tabella1_025_N200_Training.csv')
df1Test = pd.read_csv('/Users/giuspru/Documents/Tesi_mac/Test_Split_25_N200/Tabella1_025_N200_Test.csv')
df2Training = pd.read_csv('/Users/giuspru/Documents/Tesi_mac/Test_Split_25_N200/Tabella2_025_N200_Training.csv')
df2Test = pd.read_csv('/Users/giuspru/Documents/Tesi_mac/Test_Split_25_N200/Tabella2_025_N200_Test.csv')
df3Training = pd.read_csv('/Users/giuspru/Documents/Tesi_mac/Test_Split_25_N200/Tabella3_025_N200_Training.csv')
df3Test = pd.read_csv('/Users/giuspru/Documents/Tesi_mac/Test_Split_25_N200/Tabella3_025_N200_Test.csv')

# %%
#df1Training = pd.read_csv('/home/giuseppe/Scrivania/Test_Split25_N200/Tabella1_025_N200_Training.csv')
#df1Test = pd.read_csv('/home/giuseppe/Scrivania/Test_Split25_N200/Tabella1_025_N200_Test.csv')
#df2Training = pd.read_csv('/home/giuseppe/Scrivania/Test_Split25_N200/Tabella2_025_N200_Training.csv')
#df2Test = pd.read_csv('/home/giuseppe/Scrivania/Test_Split25_N200/Tabella2_025_N200_Test.csv')
#df3Training = pd.read_csv('/home/giuseppe/Scrivania/Test_Split25_N200/Tabella3_025_N200_Training.csv')
#df3Test = pd.read_csv('/home/giuseppe/Scrivania/Test_Split25_N200/Tabella3_025_N200_Test.csv')

# %%
df1Training
# Out:
#                Features                         ind1   \
# 0               Density       0.05253 +/-    0.00768
# 1          Com. Density       0.25195 +/-    0.04016
# 2         Depriv. Index       0.10679 +/-    0.02169
# 3              Latitude       0.68402 +/-    0.07271
# 4       Old Young Ratio       0.08613 +/-    0.01889
# 5             Avg. PM10       0.15611 +/-    0.03574
# 6               Avg. NO       0.20293 +/-    0.04562
# 7             Avg. PANS       0.05013 +/-    0.01101
# 8              Avg. SO2       0.06589 +/-    0.01256
# 9          Random Feat.       0.07368 +/-    0.01648
#
#                          ind2    RMSE prima Posizione   \
# 0     -0.00525 +/-    0.01012                      0.0
# 1      0.06938 +/-    0.03684                      0.0
# 2      0.01329 +/-    0.01973                      0.0
# 3      0.28289 +/-    0.05829                    100.0
# 4      0.00726 +/-    0.01734                      0.0
# 5      0.01489 +/-    0.03108                      0.0
# 6      0.02685 +/-    0.04045                      0.0
# 7      0.00129 +/-    0.00986                      0.0
# 8      0.00082 +/-    0.01242                      0.0
# 9      0.00541 +/-    0.01452                      0.0
#
#     RMSE Seconda Posizione    R2 Prima Posizione    R2 Seconda Posizione
# 0                       0.0                   0.0                     0.5
# 1                      76.0                   0.0                    83.0
# 2                       0.0                   0.0                     1.5
# 3                       0.0                 100.0                     0.0
# 4                       0.0                   0.0                     5.5
# 5                       1.0                   0.0                     3.0
# 6                      23.0                   0.0                     5.5
# 7                       0.0                   0.0                     1.0
# 8                       0.0                   0.0                     0.0
# 9                       0.0                   0.0                     0.0

# %%
df1Training
# Out:
#                Features                         ind1   \
# 0               Density       0.05253 +/-    0.00768
# 1          Com. Density       0.25195 +/-    0.04016
# 2         Depriv. Index       0.10679 +/-    0.02169
# 3              Latitude       0.68402 +/-    0.07271
# 4       Old Young Ratio       0.08613 +/-    0.01889
# 5             Avg. PM10       0.15611 +/-    0.03574
# 6               Avg. NO       0.20293 +/-    0.04562
# 7             Avg. PANS       0.05013 +/-    0.01101
# 8              Avg. SO2       0.06589 +/-    0.01256
# 9          Random Feat.       0.07368 +/-    0.01648
#
#                          ind2    RMSE prima Posizione   \
# 0     -0.00525 +/-    0.01012                      0.0
# 1      0.06938 +/-    0.03684                      0.0
# 2      0.01329 +/-    0.01973                      0.0
# 3      0.28289 +/-    0.05829                    100.0
# 4      0.00726 +/-    0.01734                      0.0
# 5      0.01489 +/-    0.03108                      0.0
# 6      0.02685 +/-    0.04045                      0.0
# 7      0.00129 +/-    0.00986                      0.0
# 8      0.00082 +/-    0.01242                      0.0
# 9      0.00541 +/-    0.01452                      0.0
#
#     RMSE Seconda Posizione    R2 Prima Posizione    R2 Seconda Posizione
# 0                       0.0                   0.0                     0.5
# 1                      76.0                   0.0                    83.0
# 2                       0.0                   0.0                     1.5
# 3                       0.0                 100.0                     0.0
# 4                       0.0                   0.0                     5.5
# 5                       1.0                   0.0                     3.0
# 6                      23.0                   0.0                     5.5
# 7                       0.0                   0.0                     1.0
# 8                       0.0                   0.0                     0.0
# 9                       0.0                   0.0                     0.0

# %%
plt.subplots(figsize = (23 ,15))

plt.subplot(2,2,1)
y = df1Training[' RMSE Seconda Posizione ']
z = df1Training[' RMSE prima Posizione ']
x = df1Training['Features ']
X_axis = np.arange(len(x))
plt.xticks(X_axis , x )
plt.yticks(np.arange(0 , 150 , 5))
plt.bar(X_axis  , y , 0.4 , label = 'Seconda Posizione' , color = 'orange'  )
plt.bar(X_axis , z , 0.4 , label = 'Prima Posizione' , color = 'blue')
plt.xticks(rotation = 45)
plt.xticks(ha = 'center')
plt.xlabel("Features")
plt.ylabel("% Importance of feature")
plt.title('Training RMSE 0.25 all features')
plt.legend()

plt.subplot(2,2,2) #Questo funziona 
y = df1Test[' RMSE Seconda Posizione ']
z = df1Test[' RMSE prima Posizione ']
x = df1Test['Features ']
X_axis = np.arange(len(x))
plt.xticks(X_axis , x )
plt.yticks(np.arange(0 , 150 , 5))
plt.bar(X_axis + 0.2 , y , 0.4 ,   label = 'Seconda Posizione' , color = 'orange')
plt.bar(X_axis - 0.2 , z  , 0.4 ,  label = 'Prima Posizione' , color = 'blue')
plt.xticks(rotation = 45)
plt.xticks(ha = 'center')
plt.xlabel("Features")
plt.ylabel("% Importance of feature")
plt.title('Test RMSE 0.25 all features')
plt.legend()

plt.subplot(2,2,3)
y = df1Training[' R2 Prima Posizione ']
z = df1Training[' R2 Seconda Posizione ']
x = df1Training['Features ']
X_axis = np.arange(len(x))
plt.xticks(X_axis , x )
plt.xticks(X_axis , x )
plt.yticks(np.arange(0 , 150 , 5))
plt.bar(X_axis  , y , 0.4 ,label = 'Seconda Posizione' , color = 'orange'  )
plt.bar(X_axis , z , 0.4 , label = 'Prima Posizione' , color = 'blue')
plt.xticks(rotation = 45)
plt.xticks(ha = 'center')
plt.xlabel("Features")
plt.ylabel("% Importance of feature")
plt.title('Training R2 0.25 all features')
plt.legend()

plt.subplot(2,2,4)
y = df1Test[' R2 Prima Posizione ']
z = df1Test[' R2 Seconda Posizione ']
x = df1Test['Features ']
X_axis = np.arange(len(x))
plt.xticks(X_axis , x )
plt.yticks(np.arange(0 , 150 , 5))
plt.bar(X_axis  , y , 0.4, label = 'Seconda Posizione' , color = 'orange'  )
plt.bar(X_axis , z , 0.4 ,  label = 'Prima Posizione' , color = 'blue')
plt.xticks(rotation = 45)
plt.xticks(ha = 'center')
plt.xlabel("Features")
plt.ylabel("% Importance of feature")
plt.title('Test R2 0.25 all features')
plt.legend()

plt.tight_layout()

# %%
plt.subplots(figsize = (23 ,15))

plt.subplot(2,2,1)
y = df2Training[' RMSE Seconda Posizione ']
z = df2Training[' RMSE prima Posizione ']
x = df2Training['Features ']
X_axis = np.arange(len(x))
plt.xticks(X_axis , x )
plt.yticks(np.arange(0 , 150 , 5))
plt.bar(X_axis + 0.2  , y , 0.4 , label = 'Seconda Posizione' , color = 'orange'  )
plt.bar(X_axis - 0.2 , z , 0.4 , label = 'Prima Posizione' , color = 'blue')
plt.xticks(rotation = 45)
plt.xticks(ha = 'center')
plt.xlabel("Features")
plt.ylabel("% Importance of feature")
plt.title('Training RMSE 0.25 all features without latitude')
plt.legend()

plt.subplot(2,2,2) #Questo funziona 
y = df2Test[' RMSE Seconda Posizione ']
z = df2Test[' RMSE prima Posizione ']
x = df2Test['Features ']
X_axis = np.arange(len(x))
plt.xticks(X_axis , x )
plt.yticks(np.arange(0 , 150 , 5))
plt.bar(X_axis + 0.2 , y , 0.4 ,   label = 'Seconda Posizione' , color = 'orange')
plt.bar(X_axis - 0.2 , z  , 0.4 ,  label = 'Prima Posizione' , color = 'blue')
plt.xticks(rotation = 45)
plt.xticks(ha = 'center')
plt.xlabel("Features")
plt.ylabel("% Importance of feature")
plt.title('Test RMSE 0.25 all features without latitude')
plt.legend()

plt.subplot(2,2,3)
y = df2Training[' R2 Prima Posizione ']
z = df2Training[' R2 Seconda Posizione ']
x = df2Training['Features ']
X_axis = np.arange(len(x))
plt.xticks(X_axis , x )
plt.xticks(X_axis , x )
plt.yticks(np.arange(0 , 150 , 5))
plt.bar(X_axis + 0.2  , y , 0.4 ,label = 'Seconda Posizione' , color = 'orange'  )
plt.bar(X_axis - 0.2 , z , 0.4 , label = 'Prima Posizione' , color = 'blue')
plt.xticks(rotation = 45)
plt.xticks(ha = 'center')
plt.xlabel("Features")
plt.ylabel("% Importance of feature")
plt.title('Training R2 0.25 all features without latitude')
plt.legend()

plt.subplot(2,2,4)
y = df2Test[' R2 Prima Posizione ']
z = df2Test[' R2 Seconda Posizione ']
x = df2Test['Features ']
X_axis = np.arange(len(x))
plt.xticks(X_axis , x )
plt.yticks(np.arange(0 , 150 , 5))
plt.bar(X_axis + 0.2  , y , 0.4, label = 'Seconda Posizione' , color = 'orange'  )
plt.bar(X_axis - 0.2 , z , 0.4 ,  label = 'Prima Posizione' , color = 'blue')
plt.xticks(rotation = 45)
plt.xticks(ha = 'center')
plt.xlabel("Features")
plt.ylabel("% Importance of feature")
plt.title('Test R2 0.25 all features without latitude')
plt.legend()

plt.tight_layout()

# %%
plt.subplots(figsize = (23 ,15))

plt.subplot(2,2,1)
y = df3Training[' RMSE Seconda Posizione ']
z = df3Training[' RMSE prima Posizione ']
x = df3Training['Features ']
X_axis = np.arange(len(x))
plt.xticks(X_axis , x )
plt.yticks(np.arange(0 , 150 , 5))
plt.bar(X_axis + 0.2  , y , 0.4 , label = 'Seconda Posizione' , color = 'orange'  )
plt.bar(X_axis - 0.2 , z , 0.4 , label = 'Prima Posizione' , color = 'blue')
plt.xticks(rotation = 45)
plt.xticks(ha = 'center')
plt.xlabel("Features")
plt.ylabel("% Importance of feature")
plt.title('Training RMSE 0.25 all features without latitude and comm. density')
plt.legend()

plt.subplot(2,2,2) #Questo funziona 
y = df3Test[' RMSE Seconda Posizione ']
z = df3Test[' RMSE prima Posizione ']
x = df3Test['Features ']
X_axis = np.arange(len(x))
plt.xticks(X_axis , x )
plt.yticks(np.arange(0 , 150 , 5))
plt.bar(X_axis + 0.2 , y , 0.4 ,   label = 'Seconda Posizione' , color = 'orange')
plt.bar(X_axis - 0.2 , z  , 0.4 ,  label = 'Prima Posizione' , color = 'blue')
plt.xticks(rotation = 45)
plt.xticks(ha = 'center')
plt.xlabel("Features")
plt.ylabel("% Importance of feature")
plt.title('Test RMSE 0.25 all features without latitude and comm. density')
plt.legend()

plt.subplot(2,2,3)
y = df3Training[' R2 Prima Posizione ']
z = df3Training[' R2 Seconda Posizione ']
x = df3Training['Features ']
X_axis = np.arange(len(x))
plt.xticks(X_axis , x )
plt.xticks(X_axis , x )
plt.yticks(np.arange(0 , 150 , 5))
plt.bar(X_axis + 0.2  , y , 0.4 ,label = 'Seconda Posizione' , color = 'orange'  )
plt.bar(X_axis - 0.2 , z , 0.4 , label = 'Prima Posizione' , color = 'blue')
plt.xticks(rotation = 45)
plt.xticks(ha = 'center')
plt.xlabel("Features")
plt.ylabel("% Importance of feature")
plt.title('Training R2 0.25 all features without latitude and comm. density')
plt.legend()

plt.subplot(2,2,4)
y = df3Test[' R2 Prima Posizione ']
z = df3Test[' R2 Seconda Posizione   ']
x = df3Test['Features ']
X_axis = np.arange(len(x))
plt.xticks(X_axis , x )
plt.yticks(np.arange(0 , 150 , 5))
plt.bar(X_axis + 0.2  , y , 0.4, label = 'Seconda Posizione' , color = 'orange'  )
plt.bar(X_axis - 0.2 , z , 0.4 ,  label = 'Prima Posizione' , color = 'blue')
plt.xticks(rotation = 45)
plt.xticks(ha = 'center')
plt.xlabel("Features")
plt.ylabel("% Importance of feature")
plt.title('Test R2 0.25 all features without latitude and comm. density')
plt.legend()

plt.tight_layout()
