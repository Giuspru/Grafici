# %%
import pandas as pd 
import numpy as np 
import matplotlib as mpl 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1Training = pd.read_csv('/home/giuseppe/Scrivania/Test_Split30_N200/Tabella1_030_N200_Training.csv')
df1Test = pd.read_csv('/home/giuseppe/Scrivania/Test_Split30_N200/Tabella1_030_N200_Test.csv')
df2Training = pd.read_csv('/home/giuseppe/Scrivania/Test_Split30_N200/Tabella2_030_N200_Training.csv')
df2Test = pd.read_csv('/home/giuseppe/Scrivania/Test_Split30_N200/Tabella2_030_N200_Test.csv')
df3Training = pd.read_csv('/home/giuseppe/Scrivania/Test_Split30_N200/Tabella3_030_N200_Training.csv')
df3Test = pd.read_csv('/home/giuseppe/Scrivania/Test_Split30_N200/Tabella3_030_N200_Test.csv')

# %%
df2Training
# Out:
#                Features                         ind1   \
# 0               Density       0.06936 +/-    0.01345
# 1          Com. Density       0.58870 +/-    0.11455
# 2         Depriv. Index       0.22331 +/-    0.05242
# 3       Old Young Ratio       0.11367 +/-    0.02441
# 4             Avg. PM10       0.25076 +/-    0.07361
# 5               Avg. NO       0.34754 +/-    0.09911
# 6             Avg. PANS       0.07685 +/-    0.02032
# 7              Avg. SO2       0.09307 +/-    0.02104
# 8          Random Feat.       0.08831 +/-    0.02155
#
#                          ind2    RMSE prima Posizione   \
# 0     -0.00262 +/-    0.01210                      0.0
# 1      0.23724 +/-    0.05214                     90.0
# 2      0.05875 +/-    0.02757                      0.0
# 3      0.01034 +/-    0.01870                      0.0
# 4      0.04859 +/-    0.03576                      0.5
# 5      0.08470 +/-    0.04673                      9.5
# ...

# %%
df2Test
# Out:
#                Features                         ind1   \
# 0               Density      -0.00452 +/-    0.02135
# 1          Com. Density       0.47950 +/-    0.13242
# 2         Depriv. Index       0.11946 +/-    0.05940
# 3       Old Young Ratio       0.01998 +/-    0.03535
# 4             Avg. PM10       0.10328 +/-    0.07839
# 5               Avg. NO       0.17847 +/-    0.10911
# 6             Avg. PANS       0.01621 +/-    0.02436
# 7              Avg. SO2       0.01601 +/-    0.02807
# 8          Random Feat.       0.01912 +/-    0.02877
#
#                          ind2    RMSE prima Posizione   \
# 0     -0.00185 +/-    0.01159                      0.0
# 1      0.23458 +/-    0.05170                     99.0
# 2      0.05894 +/-    0.02602                      0.0
# 3      0.00983 +/-    0.01719                      0.0
# 4      0.04748 +/-    0.03429                      0.0
# 5      0.08345 +/-    0.04386                      1.0
# ...

# %%
df2Test["             Features "]
# Out:
# 0                 Density
# 1            Com. Density
# 2           Depriv. Index
# 3                Latitude
# 4         Old Young Ratio
# 5               Avg. PM10
# 6                 Avg. NO
# 7               Avg. PANS
# 8                Avg. SO2
# 9            Random Feat.
# Name:          Features , dtype: object

# %%
y = df1Training[' RMSE Seconda Posizione ']
z = df1Training[' RMSE prima Posizione ']
x = df1Training["         Features "]
fig , ax  = plt.subplots(figsize=(16 , 5) )
X_axis = np.arange(len(x))
plt.xticks(X_axis , x )
plt.yticks(np.arange(0 , 150 , 5))
plt.bar(X_axis + 0.2 , y , 0.4 , label = 'Seconda Posizione' , color = 'orange')
plt.bar(X_axis - 0.2 , z , 0.4 , label = 'Prima Posizione' , color = 'blue')
plt.xlabel("Features")
plt.ylabel("% Importance of feature")
plt.title('Training RMSE 0.30 all features')
plt.legend()

# %%
y = df1Test[' RMSE Seconda Posizione ']
z = df1Test[' RMSE prima Posizione ']
x = df1Test["            Features "]
fig , ax  = plt.subplots(figsize=(16 , 5) )
X_axis = np.arange(len(x))
plt.xticks(X_axis , x )
plt.yticks(np.arange(0 , 150 , 5))
plt.bar(X_axis + 0.2 , y , 0.4 , label = 'Seconda Posizione' , color = 'm')
plt.bar(X_axis - 0.2 , z , 0.4 , label = 'Prima Posizione' , color = 'yellow')
plt.xlabel("Features")
plt.ylabel("% Importance of feature")
plt.title('Test RMSE 0.30 all features')
plt.legend()

# %%
y = df2Training[' RMSE Seconda Posizione ']
z = df2Training[' RMSE prima Posizione ']
x = df2Training["            Features "]
fig , ax  = plt.subplots(figsize=(16 , 5) )
X_axis = np.arange(len(x))
plt.xticks(X_axis , x )
plt.yticks(np.arange(0 , 150 , 5))
plt.bar(X_axis + 0.2 , y , 0.4 , label = 'Seconda Posizione' , color = 'orange')
plt.bar(X_axis - 0.2 , z , 0.4 , label = 'Prima Posizione' , color = 'blue')
plt.xlabel("Features")
plt.ylabel("% Importance of feature")
plt.title('Training RMSE 0.30 all features without latitude ')
plt.legend()

# %%
y = df2Test[' RMSE Seconda Posizione ']
z = df2Test[' RMSE prima Posizione ']
x = df2Test["             Features "]
fig , ax  = plt.subplots(figsize=(16 , 5) )
X_axis = np.arange(len(x))
plt.xticks(X_axis , x )
plt.yticks(np.arange(0 , 150 , 5))
plt.bar(X_axis + 0.2 , y , 0.4 , label = 'Seconda Posizione' , color = 'm')
plt.bar(X_axis - 0.2 , z , 0.4 , label = 'Prima Posizione' , color = 'yellow')
plt.xlabel("Features")
plt.ylabel("% Importance of feature")
plt.title('Test RMSE 0.30 all features without latitude ')
plt.legend()

# %%
y = df3Training[' RMSE Seconda Posizione ']
z = df3Training[' RMSE prima Posizione ']
x = df3Training['             Features ']
fig , ax  = plt.subplots(figsize=(16 , 5) )
X_axis = np.arange(len(x))
plt.xticks(X_axis , x )
plt.yticks(np.arange(0 , 150 , 5))
plt.bar(X_axis + 0.2 , y , 0.4 , label = 'Seconda Posizione' , color = 'orange')
plt.bar(X_axis - 0.2 , z , 0.4 , label = 'Prima Posizione' , color = 'blue')
plt.xlabel("Features")
plt.ylabel("% Importance of feature")
plt.title('Training RMSE 0.30 all features without latitude and commuted density ')
plt.legend()

# %%
y = df3Test[' RMSE Seconda Posizione ']
z = df3Test[' RMSE prima Posizione ']
x = df3Test["             Features "]
fig , ax  = plt.subplots(figsize=(16 , 5) )
X_axis = np.arange(len(x))
plt.xticks(X_axis , x )
plt.yticks(np.arange(0 , 150 , 5))
plt.bar(X_axis + 0.2 , y , 0.4 , label = 'Seconda Posizione' , color = 'm')
plt.bar(X_axis - 0.2 , z , 0.4 , label = 'Prima Posizione' , color = 'yellow')
plt.xlabel("Features")
plt.ylabel("% Importance of feature")
plt.title('Test RMSE 0.30 all features without latitude  and commuted density')
plt.legend()

# %%
y = df1Training[' R2 Prima Posizione ']
z = df1Training[' R2 Seconda Posizione ']
x = df1Training['         Features ']
fig , ax  = plt.subplots(figsize=(16 , 5) )
X_axis = np.arange(len(x))
plt.xticks(X_axis , x )
plt.yticks(np.arange(0 , 150 , 5))
plt.bar(X_axis + 0.2 , y , 0.4 , label = 'Seconda Posizione' , color = 'orange')
plt.bar(X_axis - 0.2 , z , 0.4 , label = 'Prima Posizione' , color = 'blue')
plt.xlabel("Features")
plt.ylabel("% Importance of feature")
plt.title('Training R2 0.30 all features')
plt.legend()

# %%
y = df1Test[' R2 Prima Posizione ']
z = df1Test[' R2 Seconda Posizione ']
x = df1Test['            Features ']
fig , ax  = plt.subplots(figsize=(16 , 5) )
X_axis = np.arange(len(x))
plt.xticks(X_axis , x )
plt.yticks(np.arange(0 , 150 , 5))
plt.bar(X_axis + 0.2 , y , 0.4 , label = 'Seconda Posizione' , color = 'm')
plt.bar(X_axis - 0.2 , z , 0.4 , label = 'Prima Posizione' , color = 'yellow')
plt.xlabel("Features")
plt.ylabel("% Importance of feature")
plt.title('Test R2 0.30 all features')
plt.legend()

# %%
y = df2Training[' R2 Prima Posizione ']
z = df2Training[' R2 Seconda Posizione ']
x = df2Training['            Features ']
fig , ax  = plt.subplots(figsize=(16 , 5) )
X_axis = np.arange(len(x))
plt.xticks(X_axis , x )
plt.yticks(np.arange(0 , 150 , 5))
plt.bar(X_axis + 0.2 , y , 0.4 , label = 'Seconda Posizione' , color = 'orange')
plt.bar(X_axis - 0.2 , z , 0.4 , label = 'Prima Posizione' , color = 'blue')
plt.xlabel("Features")
plt.ylabel("% Importance of feature")
plt.title('Training R2 0.30 all features without latitude')
plt.legend()

# %%
y = df2Test[' R2 Prima Posizione ']
z = df2Test[' R2 Seconda Posizione ']
x = df2Test['             Features ']
fig , ax  = plt.subplots(figsize=(16 , 5) )
X_axis = np.arange(len(x))
plt.xticks(X_axis , x )
plt.yticks(np.arange(0 , 150 , 5))
plt.bar(X_axis + 0.2 , y , 0.4 , label = 'Seconda Posizione' , color = 'm')
plt.bar(X_axis - 0.2 , z , 0.4 , label = 'Prima Posizione' , color = 'yellow')
plt.xlabel("Features")
plt.ylabel("% Importance of feature")
plt.title('Test R2 0.30 all features without latitude')
plt.legend()

# %%
y = df3Training[' R2 Prima Posizione ']
z = df3Training[' R2 Seconda Posizione ']
x = df3Training["             Features "]
fig , ax  = plt.subplots(figsize=(16 , 5) )
X_axis = np.arange(len(x))
plt.xticks(X_axis , x )
plt.yticks(np.arange(0 , 150 , 5))
plt.bar(X_axis + 0.2 , y , 0.4 , label = 'Seconda Posizione' , color = 'orange')
plt.bar(X_axis - 0.2 , z , 0.4 , label = 'Prima Posizione' , color = 'blue')
plt.xlabel("Features")
plt.ylabel("% Importance of feature")
plt.title('Training R2 0.30 all features without latitude and commuted density')
plt.legend()

# %%
y = df3Test[' R2 Prima Posizione ']
z = df3Test[' R2 Seconda Posizione ']
x = df3Test['             Features ']
fig , ax  = plt.subplots(figsize=(16 , 5) )
X_axis = np.arange(len(x))
plt.xticks(X_axis , x )
plt.yticks(np.arange(0 , 150 , 5))
plt.bar(X_axis + 0.2 , y , 0.4 , label = 'Seconda Posizione' , color = 'm')
plt.bar(X_axis - 0.2 , z , 0.4 , label = 'Prima Posizione' , color = 'yellow')
plt.xlabel("Features")
plt.ylabel("% Importance of feature")
plt.title('Test R2 0.30 all features without latitude and commuted density')
plt.legend()
