# %%
import pandas as pd 
import numpy as np 
import matplotlib as mpl 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1Training = pd.read_csv('/Users/giuspru/Documents/Tesi_mac/Test_Split_30_N200/Tabella1_030_N200_Training.csv')
df1Test = pd.read_csv('/Users/giuspru/Documents/Tesi_mac/Test_Split_30_N200/Tabella1_030_N200_Test.csv')
df2Training = pd.read_csv('/Users/giuspru/Documents/Tesi_mac/Test_Split_30_N200/Tabella2_030_N200_Training.csv')
df2Test = pd.read_csv('/Users/giuspru/Documents/Tesi_mac/Test_Split_30_N200/Tabella2_030_N200_Test.csv')
df3Training = pd.read_csv('/Users/giuspru/Documents/Tesi_mac/Test_Split_30_N200/Tabella3_030_N200_Training.csv')
df3Test = pd.read_csv('/Users/giuspru/Documents/Tesi_mac/Test_Split_30_N200/Tabella3_030_N200_Test.csv')

# %%
y1_Training = df3Training["             Features "]
f_importace_Training = df3Training["   ind1 "].str.split(expand = True)
x1_Training = []
x2_Training = []
for i in f_importace_Training[0]:
    x1_Training.append(float(i))

for i in f_importace_Training[2]:
    x2_Training.append(float(i))

# %%
y1_Test = df3Test["             Features "]
f_importace_Test = df3Test["   ind1 "].str.split(expand = True)
x1_Test = []
x2_Test = []
for i in f_importace_Test[0]:
    x1_Test.append(float(i))

for i in f_importace_Test[2]:
    x2_Test.append(float(i))

# %%
y1_Training_R2 = df3Training["             Features "]
f_importace_Training = df3Training[" ind2 "].str.split(expand = True)
x1_Training_R2 = []
x2_Training_R2= []
for i in f_importace_Training[0]:
    x1_Training_R2.append(float(i))

for i in f_importace_Training[2]:
    x2_Training_R2.append(float(i))

# %%
y1_Test_R2 = df3Test["             Features "]
f_importace_Test = df3Test[" ind2 "].str.split(expand = True)
x1_Test_R2 = []
x2_Test_R2 = []
for i in f_importace_Test[0]:
    x1_Test_R2.append(float(i))

for i in f_importace_Test[2]:
    x2_Test_R2.append(float(i))

# %%
plt.subplots(figsize = (27 ,15))


plt.subplot(2,2,1)
y = y1_Training
x = x1_Training
xer = x2_Training
y_axis = np.arange(len(y1_Training))
plt.xticks(np.arange(0,1.5,0.05) , size = 15)
plt.yticks(y_axis , y , size = 15)
plt.tight_layout()
plt.barh(y , x , xerr = xer , align='center' , capsize = 6 , color = 'blue')
plt.xlabel("Feature importance score" , size = 23  )
plt.title('Training RMSE Feature importance without latitude and commuter density: test size 030' , size = 20 )

plt.subplot(2,2,2)
y = y1_Test
x = x1_Test
xer = x2_Test
y_axis = np.arange(len(y1_Test))
plt.xticks(np.arange(0,1.5,0.05) , size = 15)
plt.yticks(y_axis , y , size = 15)
plt.tight_layout()
plt.barh(y , x , xerr = xer , align='center' , capsize = 6 , color = 'blue')
plt.xlabel("Feature importance score" , size = 23  )
plt.title('Test RMSE Feature importance without latitude and commuter density: test size 030' , size = 20 )

plt.subplot(2,2,3)
y = y1_Training_R2
x = x1_Training_R2
xer = x2_Training_R2
y_axis = np.arange(len(y1_Training_R2))
plt.xticks(np.arange(0,1.5,0.05) , size = 15)
plt.yticks(y_axis , y , size = 15)
plt.tight_layout()
plt.barh(y , x , xerr = xer , align='center' , capsize = 6 , color = 'blue')
plt.xlabel("Feature importance score" , size = 23  )
plt.title('Training R2 Feature importance without latitude and commuter density: test size 030' , size = 20 )

plt.subplot(2,2,4)
y = y1_Test_R2
x = x1_Test_R2
xer = x2_Test_R2
y_axis = np.arange(len(y1_Test_R2))
plt.xticks(np.arange(0,1.5,0.05) , size = 15)
plt.yticks(y_axis , y , size = 15)
plt.tight_layout()
plt.barh(y , x , xerr = xer , align='center' , capsize = 6 , color = 'blue')
plt.xlabel("Feature importance score" , size = 23  )
plt.title('Test R2 Feature importance without latitude and commuter density: test size 030' , size = 20 )
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>
